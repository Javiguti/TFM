# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define the data for patients
patient_data = {
    "Patient": ["Patient 1", "Patient 2", "Patient 3", "Patient 4", "Patient 5",
                "Patient 6", "Patient 7", "Patient 8", "Patient 9", "Patient 10"],
    "Model N1": [0.619, 0.540, 0.665, 0.133, 0.380, 1.018, 0.296, 0.913, 2.634, 0.994],
    "Model N2": [0.082, 0.587, 7.763, 0.827, 0.088, 7.334, 0.118, 1.908, 9.371, 2.032],
    "Model N3": [1.503, 0.333, 8.057, 1.233, 0.185, 7.484, 0.485, 2.008, 9.451, 2.677],
    "Dataset Size": [10981, 15000, 9172, 15000, 10267, 10022, 8445, 12053, 16327, 13487]
}

# Define the data for healthy individuals
healthy_data = {
    "Healthy": ["Healthy 1", "Healthy 2", "Healthy 3", "Healthy 4", "Healthy 5",
                "Healthy 6", "Healthy 7", "Healthy 8", "Healthy 9", "Healthy 10"],
    "Model N1": [2.019, 0.391, 1.605, 0.174, 0.168, 1.007, 1.754, 1.628, 2.400, 0.342],
    "Model N2": [1.461, 0.223, 1.736, 3.245, 0.326, 0.161, 0.135, 1.085, 2.552, 0.235],
    "Model N3": [1.661, 0.433, 2.094, 3.793, 0.745, 0.322, 1.379, 0.293, 2.856, 0.598],
    "Dataset Size": [14512, 7162, 12271, 10941, 10741, 4965, 6671, 9216, 14460, 14893]
}

# Convert the dictionaries to DataFrames
patient_df = pd.DataFrame(patient_data)
healthy_df = pd.DataFrame(healthy_data)

# Plotting
plt.figure(figsize=(14, 6))

# Plot for patients
plt.subplot(1, 2, 1)
for col in ["Model N1", "Model N2", "Model N3"]:
    plt.plot(patient_df["Patient"], patient_df[col], marker='o', label=col)
plt.title('Patients')
plt.xlabel('Patients')
plt.ylabel('Percentage of ARG classified sequences (%)')
plt.xticks(rotation=45)
plt.legend()

# Plot for healthy individuals
plt.subplot(1, 2, 2)
for col in ["Model N1", "Model N2", "Model N3"]:
    plt.plot(healthy_df["Healthy"], healthy_df[col], marker='o', label=col)
plt.title('Healthy Individuals')
plt.xlabel('Healthy Individuals')
plt.ylabel('Percentage of ARG classified sequences (%)')
plt.xticks(rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the data for patients
patient_data = {
    "Patient": ["Patient 1", "Patient 2", "Patient 3", "Patient 4", "Patient 5",
                "Patient 6", "Patient 7", "Patient 8", "Patient 9", "Patient 10"],
    "Model N1": [0.619, 0.540, 0.665, 0.133, 0.380, 1.018, 0.296, 0.913, 2.634, 0.994],
    "Model N2": [0.082, 0.587, 7.763, 0.827, 0.088, 7.334, 0.118, 1.908, 9.371, 2.032],
    "Model N3": [1.503, 0.333, 8.057, 1.233, 0.185, 7.484, 0.485, 2.008, 9.451, 2.677],
    "Dataset Size": [10981, 15000, 9172, 15000, 10267, 10022, 8445, 12053, 16327, 13487]
}

# Define the data for healthy individuals
healthy_data = {
    "Healthy": ["Healthy 1", "Healthy 2", "Healthy 3", "Healthy 4", "Healthy 5",
                "Healthy 6", "Healthy 7", "Healthy 8", "Healthy 9", "Healthy 10"],
    "Model N1": [2.019, 0.391, 1.605, 0.174, 0.168, 1.007, 1.754, 1.628, 2.400, 0.342],
    "Model N2": [1.461, 0.223, 1.736, 3.245, 0.326, 0.161, 0.135, 1.085, 2.552, 0.235],
    "Model N3": [1.661, 0.433, 2.094, 3.793, 0.745, 0.322, 1.379, 0.293, 2.856, 0.598],
    "Dataset Size": [14512, 7162, 12271, 10941, 10741, 4965, 6671, 9216, 14460, 14893]
}

# Convert the dictionaries to DataFrames
patient_df = pd.DataFrame(patient_data)
healthy_df = pd.DataFrame(healthy_data)

# Plotting
plt.figure(figsize=(14, 6))

# Plot for patients
plt.subplot(1, 2, 1)

for col in ["Model N1", "Model N2", "Model N3"]:
    plt.plot(patient_df["Patient"], patient_df[col], marker='o', label=col)
plt.title('Patients')
plt.xlabel('Patients')
plt.ylabel('Percentage of ARG classified sequences (%)')
plt.xticks(rotation=45)
plt.legend()

# Plot for healthy individuals
plt.subplot(1, 2, 2)
for col in ["Model N1", "Model N2", "Model N3"]:
    plt.plot(healthy_df["Healthy"], healthy_df[col], marker='o', label=col)
plt.title('Healthy Individuals')
plt.xlabel('Healthy Individuals')
plt.ylabel('Percentage of ARG classified sequences (%)')
plt.xticks(rotation=45)
plt.legend()
plt.ylim(0,10)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the data for patients
patient_data = {
    "Patient": ["Patient 1", "Patient 2", "Patient 3", "Patient 4", "Patient 5",
                "Patient 6", "Patient 7", "Patient 8", "Patient 9", "Patient 10"],
    "Model N1": [0.619, 0.540, 0.665, 0.133, 0.380, 1.018, 0.296, 0.913, 2.634, 0.994],
    "Model N2": [0.082, 0.587, 7.763, 0.827, 0.088, 7.334, 0.118, 1.908, 9.371, 2.032],
    "Model N3": [1.503, 0.333, 8.057, 1.233, 0.185, 7.484, 0.485, 2.008, 9.451, 2.677],
    "Dataset Size": [10981, 15000, 9172, 15000, 10267, 10022, 8445, 12053, 16327, 13487]
}

# Define the data for healthy individuals
healthy_data = {
    "Healthy": ["Healthy 1", "Healthy 2", "Healthy 3", "Healthy 4", "Healthy 5",
                "Healthy 6", "Healthy 7", "Healthy 8", "Healthy 9", "Healthy 10"],
    "Model N1": [2.019, 0.391, 1.605, 0.174, 0.168, 1.007, 1.754, 1.628, 2.400, 0.342],
    "Model N2": [1.461, 0.223, 1.736, 3.245, 0.326, 0.161, 0.135, 1.085, 2.552, 0.235],
    "Model N3": [1.661, 0.433, 2.094, 3.793, 0.745, 0.322, 1.379, 0.293, 2.856, 0.598],
    "Dataset Size": [14512, 7162, 12271, 10941, 10741, 4965, 6671, 9216, 14460, 14893]
}

# Convert the dictionaries to DataFrames
patient_df = pd.DataFrame(patient_data)
healthy_df = pd.DataFrame(healthy_data)

# Set the positions for the groups
ind = np.arange(len(patient_df))

# Define the width for each bar
width = 0.35

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
#plt.ylim(0, 10)
# Plot for patients
ax1.bar(ind - width, patient_df["Model N1"], width, label='Model N1', color='b')
ax1.bar(ind, patient_df["Model N2"], width, label='Model N2', color='g')
ax1.bar(ind + width, patient_df["Model N3"], width, label='Model N3', color='r')

ax1.set_ylabel('Percentage of ARG classified sequences (%)')
ax1.set_title('Patients')
ax1.set_xticks(ind)
ax1.set_xticklabels(patient_df["Patient"], rotation=45)
ax1.legend()

# Plot for healthy individuals
ax2.bar(ind - width, healthy_df["Model N1"], width, label='Model N1', color='b', alpha=0.5, hatch='//')
ax2.bar(ind, healthy_df["Model N2"], width, label='Model N2', color='g', alpha=0.5, hatch='//')
ax2.bar(ind + width, healthy_df["Model N3"], width, label='Model N3', color='r', alpha=0.5, hatch='//')

ax2.set_ylabel('Percentage of ARG classified sequences (%)')
ax2.set_title('Healthy Individuals')
ax2.set_xticks(ind)
ax2.set_xticklabels(healthy_df["Healthy"], rotation=45)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the data for patients
patient_data = {
    "Patient": ["Patient 1", "Patient 2", "Patient 3", "Patient 4", "Patient 5",
                "Patient 6", "Patient 7", "Patient 8", "Patient 9", "Patient 10"],
    "Model N1": [0.619, 0.540, 0.665, 0.133, 0.380, 1.018, 0.296, 0.913, 2.634, 0.994],
    "Model N2": [0.082, 0.587, 7.763, 0.827, 0.088, 7.334, 0.118, 1.908, 9.371, 2.032],
    "Model N3": [1.503, 0.333, 8.057, 1.233, 0.185, 7.484, 0.485, 2.008, 9.451, 2.677],
    "Dataset Size": [10981, 15000, 9172, 15000, 10267, 10022, 8445, 12053, 16327, 13487]
}

# Define the data for healthy individuals
healthy_data = {
    "Healthy": ["Healthy 1", "Healthy 2", "Healthy 3", "Healthy 4", "Healthy 5",
                "Healthy 6", "Healthy 7", "Healthy 8", "Healthy 9", "Healthy 10"],
    "Model N1": [2.019, 0.391, 1.605, 0.174, 0.168, 1.007, 1.754, 1.628, 2.400, 0.342],
    "Model N2": [1.461, 0.223, 1.736, 3.245, 0.326, 0.161, 0.135, 1.085, 2.552, 0.235],
    "Model N3": [1.661, 0.433, 2.094, 3.793, 0.745, 0.322, 1.379, 0.293, 2.856, 0.598],
    "Dataset Size": [14512, 7162, 12271, 10941, 10741, 4965, 6671, 9216, 14460, 14893]
}

# Convert the dictionaries to DataFrames
patient_df = pd.DataFrame(patient_data)
healthy_df = pd.DataFrame(healthy_data)

# Set the positions for the groups
ind = np.arange(len(patient_df))

# Define the width for each bar
width = 0.35

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
plt.ylim(0, 10)
# Plot for patients
ax1.bar(ind - width, patient_df["Model N1"], width, label='Model N1', color='b')
ax1.bar(ind, patient_df["Model N2"], width, label='Model N2', color='g')
ax1.bar(ind + width, patient_df["Model N3"], width, label='Model N3', color='r')

ax1.set_ylabel('Percentage of ARG classified sequences (%)')
ax1.set_title('Patients')
ax1.set_xticks(ind)
ax1.set_xticklabels(patient_df["Patient"], rotation=45)
ax1.legend()

# Plot for healthy individuals
ax2.bar(ind - width, healthy_df["Model N1"], width, label='Model N1', color='b', alpha=0.5, hatch='//')
ax2.bar(ind, healthy_df["Model N2"], width, label='Model N2', color='g', alpha=0.5, hatch='//')
ax2.bar(ind + width, healthy_df["Model N3"], width, label='Model N3', color='r', alpha=0.5, hatch='//')

ax2.set_ylabel('Percentage of ARG classified sequences (%)')
ax2.set_title('Healthy Individuals')
ax2.set_xticks(ind)
ax2.set_xticklabels(healthy_df["Healthy"], rotation=45)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the data for patients
patient_data = {
    "Patient": ["Patient 1", "Patient 2", "Patient 3", "Patient 4", "Patient 5",
                "Patient 6", "Patient 7", "Patient 8", "Patient 9", "Patient 10"],
    "Model N1": [0.619, 0.540, 0.665, 0.133, 0.380, 1.018, 0.296, 0.913, 2.634, 0.994],
    "Model N2": [0.082, 0.587, 7.763, 0.827, 0.088, 7.334, 0.118, 1.908, 9.371, 2.032],
    "Model N3": [1.503, 0.333, 8.057, 1.233, 0.185, 7.484, 0.485, 2.008, 9.451, 2.677],
    "Dataset Size": [10981, 15000, 9172, 15000, 10267, 10022, 8445, 12053, 16327, 13487]
}

# Define the data for healthy individuals
healthy_data = {
    "Healthy": ["Healthy 1", "Healthy 2", "Healthy 3", "Healthy 4", "Healthy 5",
                "Healthy 6", "Healthy 7", "Healthy 8", "Healthy 9", "Healthy 10"],
    "Model N1": [2.019, 0.391, 1.605, 0.174, 0.168, 1.007, 1.754, 1.628, 2.400, 0.342],
    "Model N2": [1.461, 0.223, 1.736, 3.245, 0.326, 0.161, 0.135, 1.085, 2.552, 0.235],
    "Model N3": [1.661, 0.433, 2.094, 3.793, 0.745, 0.322, 1.379, 0.293, 2.856, 0.598],
    "Dataset Size": [14512, 7162, 12271, 10941, 10741, 4965, 6671, 9216, 14460, 14893]
}

# Convert the dictionaries to DataFrames
patient_df = pd.DataFrame(patient_data)
healthy_df = pd.DataFrame(healthy_data)

# Set the positions for the groups
ind = np.arange(len(patient_df))

# Define the width for each group
width = 0.25

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot for patients
ax.bar(ind - width, patient_df["Model N1"], width, label='Model N1', color='b')
ax.bar(ind, patient_df["Model N2"], width, label='Model N2', color='g')
ax.bar(ind + width, patient_df["Model N3"], width, label='Model N3', color='r')

# Plot for healthy individuals
ax.bar(ind - width, healthy_df["Model N1"], width, label='Model N1', color='b', alpha=0.5, hatch='//')
ax.bar(ind, healthy_df["Model N2"], width, label='Model N2', color='g', alpha=0.5, hatch='//')
ax.bar(ind + width, healthy_df["Model N3"], width, label='Model N3', color='r', alpha=0.5, hatch='//')

ax.set_ylabel('Percentage of ARG classified sequences (%)')
ax.set_title('Percentage of ARG classified sequences by Model for Patients and Healthy Individuals')
ax.set_xticks(ind)
ax.set_xticklabels(patient_df["Patient"], rotation=45)
ax.legend(['Model N1 (Patient)', 'Model N2 (Patient)', 'Model N3 (Patient)', 
           'Model N1 (Healthy)', 'Model N2 (Healthy)', 'Model N3 (Healthy)'])

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the data for patients
patient_data = {
    "Patient": ["Patient 1", "Patient 2", "Patient 3", "Patient 4", "Patient 5",
                "Patient 6", "Patient 7", "Patient 8", "Patient 9", "Patient 10"],
    "Model N1": [0.619, 0.540, 0.665, 0.133, 0.380, 1.018, 0.296, 0.913, 2.634, 0.994],
    "Model N2": [0.082, 0.587, 7.763, 0.827, 0.088, 7.334, 0.118, 1.908, 9.371, 2.032],
    "Model N3": [1.503, 0.333, 8.057, 1.233, 0.185, 7.484, 0.485, 2.008, 9.451, 2.677],
    "Dataset Size": [10981, 15000, 9172, 15000, 10267, 10022, 8445, 12053, 16327, 13487]
}

# Define the data for healthy individuals
healthy_data = {
    "Healthy": ["Healthy 1", "Healthy 2", "Healthy 3", "Healthy 4", "Healthy 5",
                "Healthy 6", "Healthy 7", "Healthy 8", "Healthy 9", "Healthy 10"],
    "Model N1": [2.019, 0.391, 1.605, 0.174, 0.168, 1.007, 1.754, 1.628, 2.400, 0.342],
    "Model N2": [1.461, 0.223, 1.736, 3.245, 0.326, 0.161, 0.135, 1.085, 2.552, 0.235],
    "Model N3": [1.661, 0.433, 2.094, 3.793, 0.745, 0.322, 1.379, 0.293, 2.856, 0.598],
    "Dataset Size": [14512, 7162, 12271, 10941, 10741, 4965, 6671, 9216, 14460, 14893]
}

# Convert the dictionaries to DataFrames
patient_df = pd.DataFrame(patient_data)
healthy_df = pd.DataFrame(healthy_data)

# Create a new figure
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotting patients data
for i in range(len(patient_df)):
    ax.scatter(patient_df["Model N1"][i], patient_df["Model N2"][i], patient_df["Model N3"][i], 
               c='b', marker='o', label='Patients' if i == 0 else "", s=100)

# Plotting healthy individuals data
for i in range(len(healthy_df)):
    ax.scatter(healthy_df["Model N1"][i], healthy_df["Model N2"][i], healthy_df["Model N3"][i], 
               c='r', marker='^', label='Healthy Individuals' if i == 0 else "", s=100)

# Set labels and title
ax.set_xlabel('Model N1')
ax.set_ylabel('Model N2')
ax.set_zlabel('Model N3')
ax.set_title('Percentage of ARG classified sequences by Model')

# Add a legend
ax.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the data for patients
patient_data = {
    "Patient": ["Patient 1", "Patient 2", "Patient 3", "Patient 4", "Patient 5",
                "Patient 6", "Patient 7", "Patient 8", "Patient 9", "Patient 10"],
    "Model N1": [0.619, 0.540, 0.665, 0.133, 0.380, 1.018, 0.296, 0.913, 2.634, 0.994],
    "Model N2": [0.082, 0.587, 7.763, 0.827, 0.088, 7.334, 0.118, 1.908, 9.371, 2.032],
    "Model N3": [1.503, 0.333, 8.057, 1.233, 0.185, 7.484, 0.485, 2.008, 9.451, 2.677],
    "Dataset Size": [10981, 15000, 9172, 15000, 10267, 10022, 8445, 12053, 16327, 13487]
}

# Define the data for healthy individuals
healthy_data = {
    "Healthy": ["Healthy 1", "Healthy 2", "Healthy 3", "Healthy 4", "Healthy 5",
                "Healthy 6", "Healthy 7", "Healthy 8", "Healthy 9", "Healthy 10"],
    "Model N1": [2.019, 0.391, 1.605, 0.174, 0.168, 1.007, 1.754, 1.628, 2.400, 0.342],
    "Model N2": [1.461, 0.223, 1.736, 3.245, 0.326, 0.161, 0.135, 1.085, 2.552, 0.235],
    "Model N3": [1.661, 0.433, 2.094, 3.793, 0.745, 0.322, 1.379, 0.293, 2.856, 0.598],
    "Dataset Size": [14512, 7162, 12271, 10941, 10741, 4965, 6671, 9216, 14460, 14893]
}

# Convert the dictionaries to DataFrames
patient_df = pd.DataFrame(patient_data)
healthy_df = pd.DataFrame(healthy_data)

# Set the positions for the groups
ind = np.arange(len(patient_df))

# Define the width for each bar
width = 0.2

# Create a new figure
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotting patients data
ax.bar(ind - width, patient_df["Model N1"], zs=0, zdir='y', width=width, label='Model N1 (Patients)', color='b')
ax.bar(ind, patient_df["Model N2"], zs=1, zdir='y', width=width, label='Model N2 (Patients)', color='g')
ax.bar(ind + width, patient_df["Model N3"], zs=2, zdir='y', width=width, label='Model N3 (Patients)', color='r')

# Plotting healthy individuals data
ax.bar(ind - width, healthy_df["Model N1"], zs=3, zdir='y', width=width, label='Model N1 (Healthy)', color='b', alpha=0.5, hatch='//')
ax.bar(ind, healthy_df["Model N2"], zs=4, zdir='y', width=width, label='Model N2 (Healthy)', color='g', alpha=0.5, hatch='//')
ax.bar(ind + width, healthy_df["Model N3"], zs=5, zdir='y', width=width, label='Model N3 (Healthy)', color='r', alpha=0.5, hatch='//')

# Set labels and title
ax.set_xlabel('Patients and Healthy Individuals')
ax.set_ylabel('Model')
ax.set_zlabel('Percentage of ARG classified sequences (%)')
ax.set_title('Percentage of ARG classified sequences by Model for Patients and Healthy Individuals')

# Add a legend
ax.legend()

# Set ticks and tick labels
ax.set_yticks(range(6))
ax.set_yticklabels(['Model N1 (Patients)', 'Model N2 (Patients)', 'Model N3 (Patients)', 
                    'Model N1 (Healthy)', 'Model N2 (Healthy)', 'Model N3 (Healthy)'])

plt.show()

# %% [markdown]
# ### SYNTHETIC

# %%
import pandas as pd

# Data provided
patient_data = {
    "Patient": ["Patient 1", "Patient 2", "Patient 3", "Patient 4", "Patient 5",
                "Patient 6", "Patient 7", "Patient 8", "Patient 9", "Patient 10"],
    "Model N1": [13.60531828, 19.29333333, 2.006105539, 2.873333333, 5.619947404, 
                 11.46477749, 9.816459443, 9.126358583, 7.478409996, 10.78075184], #bien
    "Model N2": [12.90410709, 35.60666667, 23.44090711, 25.59333333, 10.03214181,
                 24.5659549, 28.35997632, 24.03550983, 25.25264899, 29.39868021], #bien
    "Model N3": [18.10399781, 10.13333333, 20.15918011, 16.69333333, 5.94136554, 
                 18.86848932, 17.16992303, 18.43524434, 23.97256079, 20.10083784],
    "Dataset Size": [10981, 15000, 9172, 15000, 10267, 10022, 8445, 12053, 16327, 13487]
}

healthy_data = {
    "Healthy": ["Healthy 1", "Healthy 2", "Healthy 3", "Healthy 4", "Healthy 5",
                "Healthy 6", "Healthy 7", "Healthy 8", "Healthy 9", "Healthy 10"],
    "Model N1": [12.54134509, 10.9047752, 11.70238774, 2.065624714, 1.778232939, 
                 4.974823766, 6.880527657, 6.694878472, 14.97233748, 14.42288323], #bien
    "Model N2": [32.33186329, 15.12147445, 29.65528482, 20.1078512, 25.891444,
                 12.4672709, 8.589416879, 22.29817708, 32.86307054, 32.57906399], #bien
    "Model N3": [16.41400221, 12.41273387, 13.95974248, 15.3916461, 13.78828787,
                 6.465256798, 13.55119173, 3.461371528, 15.90594744, 23.93742026], #bien
    "Dataset Size": [14512, 7162, 12271, 10941, 10741, 4965, 6671, 9216, 14460, 14893]
}


# Convert the dictionaries to DataFrames
patient_df = pd.DataFrame(patient_data)
healthy_df = pd.DataFrame(healthy_data)

# Set the positions for the groups
ind = np.arange(len(patient_df))

# Define the width for each bar
width = 0.35

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
plt.ylim(0, 40)
# Plot for patients
ax1.bar(ind - width, patient_df["Model N1"], width, label='Model N1', color='b')
ax1.bar(ind, patient_df["Model N2"], width, label='Model N2', color='g')
ax1.bar(ind + width, patient_df["Model N3"], width, label='Model N3', color='r')

ax1.set_ylabel('Percentage of ARG classified sequences (%)')
ax1.set_title('Patients')
ax1.set_xticks(ind)
ax1.set_xticklabels(patient_df["Patient"], rotation=45)
ax1.legend()

# Plot for healthy individuals
ax2.bar(ind - width, healthy_df["Model N1"], width, label='Model N1', color='b', alpha=0.5, hatch='//')
ax2.bar(ind, healthy_df["Model N2"], width, label='Model N2', color='g', alpha=0.5, hatch='//')
ax2.bar(ind + width, healthy_df["Model N3"], width, label='Model N3', color='r', alpha=0.5, hatch='//')

ax2.set_ylabel('Percentage of ARG classified sequences (%)')
ax2.set_title('Healthy Individuals')
ax2.set_xticks(ind)
ax2.set_xticklabels(healthy_df["Healthy"], rotation=45)
ax2.legend()

plt.tight_layout()
plt.show()
